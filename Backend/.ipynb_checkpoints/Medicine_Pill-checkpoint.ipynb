# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\samruddhi pai\anaconda3\lib\site-packages (8.4.46)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (1.40.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.40.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.40.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in c:\users\samruddhi pai\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (69.5.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\samruddhi pai\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow matplotlib
# Out:
# Requirement already satisfied: pillow in c:\users\samruddhi pai\anaconda3\lib\site-packages (11.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: matplotlib in c:\users\samruddhi pai\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
pip install roboflow
# Out:
# Requirement already satisfied: roboflow in c:\users\samruddhi pai\anaconda3\lib\site-packages (1.3.7)
# Requirement already satisfied: certifi in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (2025.10.5)
# Requirement already satisfied: idna==3.7 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (3.8.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: pi-heif<2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests_toolbelt in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer>=0.12.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from roboflow) (0.25.1)
# Requirement already satisfied: colorama in c:\users\samruddhi pai\anaconda3\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from typer>=0.12.0->roboflow) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from typer>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from typer>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from typer>=0.12.0->roboflow) (0.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from requests->roboflow) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\samruddhi pai\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.12.0->roboflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import shutil
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image

# %%
DATA_YAML_PATH = os.path.abspath("../Backend/data.yaml")

if os.path.exists(DATA_YAML_PATH):
    print(f"Found data.yaml at: {DATA_YAML_PATH}")
    with open(DATA_YAML_PATH, 'r') as f:
        print("\n--- YAML Content ---")
        print(f.read())
else:
    print(f"Error: Could not find data.yaml at {DATA_YAML_PATH}")
# Out:
# Found data.yaml at: C:\Users\Samruddhi pai\Desktop\Git_demo\MiMediCare\Backend\data.yaml
#
# --- YAML Content ---
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 2
# names: ['IBUPROFEN AND PARACETAMOL TABLETS', 'Medicine-Name']
#
# roboflow:
#   workspace: medicine-label
#   project: medicine-crimp
#   version: 1
#   license: Public Domain
#   url: https://universe.roboflow.com/medicine-label/medicine-crimp/dataset/1

# %%
# Load the pretrained weights (YOLOv8 Nano is best for local training)
model = YOLO('yolov8n.pt') 

print("Base model 'yolov8n' loaded successfully.")
# Out:
# Base model 'yolov8n' loaded successfully.

# %%
# Start training
# Reduce epochs to 20 or 30 if your laptop is getting too hot
results = model.train(
    data=DATA_YAML_PATH,
    epochs=20,       
    imgsz=640,       
    batch=16,        
    name='medicine_detector',
    device='cpu'     # Change to 0 if you have an NVIDIA GPU
)
# Out:
# Ultralytics 8.4.46  Python-3.12.12 torch-2.11.0+cpu CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\Samruddhi pai\Desktop\Git_demo\MiMediCare\Backend\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=medicine_detector-3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Samruddhi pai\Desktop\Git_demo\MiMediCare\Backend\runs\detect\medicine_detector-3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.30.1 ms, read: 206.536.9 MB/s, size: 155.4 KB)
# train: Scanning C:\Users\Samruddhi pai\Desktop\Git_demo\MiMediCare\Backend\train\labels.cache... 201 images, 21 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 201/201  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 174, len(boxes) = 180. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.30.0 ms, read: 191.922.6 MB/s, size: 117.5 KB)
# val: Scanning C:\Users\Samruddhi pai\Desktop\Git_demo\MiMediCare\Backend\valid\labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 17, len(boxes) = 20. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to C:\Users\Samruddhi pai\Desktop\Git_demo\MiMediCare\Backend\runs\detect\medicine_detector-3\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\Samruddhi pai\Desktop\Git_demo\MiMediCare\Backend\runs\detect\medicine_detector-3
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G       2.08      4.019       2.23         13        640: 100% ━━━━━━━━━━━━ 13/13 8.1s/it 1:457.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                    all         20         20    0.00631          1      0.344      0.072
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      1.623      3.165       1.83         22        640: 100% ━━━━━━━━━━━━ 13/13 7.3s/it 1:356.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.8s/it 3.8s
#                    all         20         20      0.961       0.25      0.545      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G       1.55      2.687      1.736         15        640: 100% ━━━━━━━━━━━━ 13/13 7.1s/it 1:336.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                    all         20         20      0.416        0.2      0.174     0.0798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G      1.594      2.522      1.677         15        640: 100% ━━━━━━━━━━━━ 13/13 7.0s/it 1:316.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                    all         20         20      0.213        0.3       0.16     0.0572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      1.482      2.327      1.625         19        640: 100% ━━━━━━━━━━━━ 13/13 7.1s/it 1:326.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                    all         20         20      0.301       0.25      0.125     0.0501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G      1.504      2.296      1.643         13        640: 100% ━━━━━━━━━━━━ 13/13 7.3s/it 1:356.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                    all         20         20      0.315        0.6      0.358      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20         0G      1.351      2.052      1.491         19        640: 100% ━━━━━━━━━━━━ 13/13 7.0s/it 1:326.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0s/it 4.0s
#                    all         20         20        0.6        0.3      0.323      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20         0G      1.342      1.891      1.508         22        640: 100% ━━━━━━━━━━━━ 13/13 6.9s/it 1:296.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5s/it 3.5s
#                    all         20         20      0.181        0.4      0.125     0.0261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20         0G      1.294      1.844      1.468         19        640: 100% ━━━━━━━━━━━━ 13/13 6.8s/it 1:285.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4s/it 3.4s
#                    all         20         20      0.216       0.45      0.131     0.0337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20         0G      1.264      1.854       1.47         18        640: 100% ━━━━━━━━━━━━ 13/13 6.7s/it 1:275.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3s/it 3.3s
#                    all         20         20      0.219        0.3     0.0921     0.0136
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20         0G      1.315      2.314      1.624         14        640: 31% ━━━╸──────── 4/13 9.6s/it 35.4s<1:278
